# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
ig, ax = plt.subplots()  
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)

# %%
y = x ** 2

# %%
ig, ax = plt.subplots()  
ax.plot(x, y)

# %%
data_points = [(1, 2),(1.5, 3),(2, 1),(2.5, 4),(3, 1),(3.5, 3)]

# %%
ig, ax = plt.subplots()  
ax.plot(data_points)
# Out:
# [<matplotlib.lines.Line2D at 0x1dc0edafa90>,
#  <matplotlib.lines.Line2D at 0x1dc0edafaf0>]
