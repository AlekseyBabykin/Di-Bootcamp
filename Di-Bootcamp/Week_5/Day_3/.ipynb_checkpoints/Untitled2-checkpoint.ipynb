# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
figure, axes_set = plt.subplots(2,2)

# %%
axes_set
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
figure, axes_set = plt.subplots(2)

# %%
x = np.linspace(1,100)
y1 = x**2
y2 = x**3

figure, axes_set = plt.subplots(2)

axes_set[0].plot(x, y1, color="red")
axes_set[1].plot(x, y2, color="green")

# %%
x = np.linspace(1,100)
y1 = x**2
y2 = x**3

figure, axes_set = plt.subplots(2)

axes_set[0].plot(x, y1, color="red")

axes_set[0].annotate('breakout', xy=(0,0), xytext=(1,2000), arrowprops={'facecolor':'black', 'shrink':10})

axes_set[1].plot(x, y2, color="green")
plt.show()

# %%
x = np.linspace(1,100,1000)
y1 = x**2
y2 = x**3

figure, axes_set = plt.subplots(2)

axes_set[0].plot(x, y1, color="red", label="main 1 line")

axes_set[0].legend(title='Legend', loc='Lower right', shadow=True)

axes_set[0].annotate('breakout', xy=(0,0), xytext=(1,2000), arrowprops={'facecolor':'black', 'shrink':10})

axes_set[1].plot(x, y2, color="green", label="main 2 line")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\CD86~1\AppData\Local\Temp/ipykernel_3276/2427841628.py in <module>
#       7 axes_set[0].plot(x, y1, color="red", label="main 1 line")
#       8
# ----> 9 axes_set[0].legend(title='Legend', loc='Lower right', shadow=True)
#      10
#      11 axes_set[0].annotate('breakout', xy=(0,0), xytext=(1,2000), arrowprops={'facecolor':'black', 'shrink':10})
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     316         if len(extra_args):
#     317             raise TypeError('legend only accepts two non-keyword arguments')
# --> 318         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     319         self.legend_._remove_method = self._remove_legend
#     320         return self.legend_
#
# ...

# %%
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

figure, axes_set = plt.subplots(2,2)
axes_set[0][0].plot(x,y)

axes_set[0][1].plot(x,-y) 

axes_set[1][0].plot(x, y**2)

axes_set[1][1].plot(x,-y**2)

plt.tight_layout()

# %%
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

figure, axes_set = plt.subplots(2,2)
axes_set[0][0].plot(x,y)
axes_set[0][0].annotate("minimum", xy=(0,-1))
axes_set[0][0].annotate(" maximum", xy=(0,1))
axes_set[0][1].plot(x,-y) 

axes_set[1][0].plot(x, y**2)

axes_set[1][1].plot(x,-y**2)

plt.tight_layout()
