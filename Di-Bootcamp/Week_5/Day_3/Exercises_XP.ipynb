# %%
from mpl_toolkits.mplot3d import Axes3D  
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 🌟 Exercise 1 :

# %% [markdown]
# # 🌟 Exercise 2 :

# %%
figure, axes_set = plt.subplots(1)
x = [1, 2, 3, 4, 5]  # Prices
y = [5, 4, 3, 2, 1]  # Demand
axes_set.plot(x,y)

# %% [markdown]
# # 🌟 Exercise 3 :

# %%
figure,axes_set = plt.subplots(1)
x = [1, 2, 3, 4, 5]  # Age
y = [75, 80, 88, 95, 105]  # Height in cm
axes_set.scatter(x,y)

# %% [markdown]
# # 🌟 Exercise 4 :

# %%
figure, axes_set = plt.subplots(1)
x = [1, 2, 3, 4, 5]  # Prices
y = [5, 4, 3, 2, 1]  # Demand
axes_set.set(title="Product Demand vs Price", xlabel="Price", ylabel="Demand")
axes_set.plot(x,y)

# %%
figure.savefig("2.png") #🌟 Exercise 6 :

# %% [markdown]
# # 🌟 Exercise 5 :

# %%
figure,axes = plt.subplots(1)
x = [1, 2, 3, 4, 5]  # Age
y = [75, 80, 88, 95, 105]  # Height in cm
axes.set(title="Children’s Height vs Age", xlabel="Age (years)", ylabel="Height (cm)")
axes.scatter(x,y)

# %% [markdown]
# # 🌟 Exercise 6 :

# %%
figure.savefig("1.png")

# %% [markdown]
# # 🌟 Exercise 7 :

# %%
import math

# %%
figure, axis = plt.subplots(1,2)
x = np.linspace(0,10)
y1 = np.sin(x)
y2 = np.cos(x)
axis[0].set(title="y = sin(x)")
axis[0].plot(x,y1)
axis[1].set(title="y = cos(x)")
axis[1].scatter(x,y2)
plt.tight_layout()

# %% [markdown]
# # 🌟 Exercise 8 :

# %%
figure, axis = plt.subplots(2)
x = np.linspace(0,10)
y1 = np.sin(x)
y2 = np.cos(x)
axis[0].set(title="y = sin(x)")
axis[0].plot(x,y1)
axis[1].set(title="y = cos(x)")
axis[1].scatter(x,y2)
plt.tight_layout()

# %% [markdown]
# # 🌟 Exercise 9 :

# %%
figure, axis = plt.subplots(2)
x = np.linspace(0,10)
y1 = np.sin(x)
y2 = np.cos(x)
axis[0].set(title="y = sin(x)")
axis[0].plot(x,y1, label="y = sin(x)")
axis[1].set(title="y = cos(x)")
axis[1].scatter(x,y2, label="y = cos(x)")
axis[0].legend()
axis[1].legend()
plt.tight_layout()

# %% [markdown]
# # 🌟 Exercise 10 :

# %%
grades = [88, 90, 95, 92, 88, 90, 88, 85, 93, 92, 90, 87, 95, 90, 88]
figure, ax = plt.subplots()
ax.hist(grades, bins=10)
# Out:
# (array([1., 0., 1., 4., 0., 4., 0., 2., 1., 2.]),
#  array([85., 86., 87., 88., 89., 90., 91., 92., 93., 94., 95.]),
#  <BarContainer object of 10 artists>)
