# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Exercise 1: Getting & Knowing Your Data (Chipo)

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
np.shape(chipo)
# Out:
# (4622, 5)

# %%
chipo.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
total_number_rows = 4622
total_number_colums = 5

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.loc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %%
chipo.iloc[0]
# Out:
# order_id                                         1
# quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 0, dtype: object

# %%
chipo.value_counts('item_name')
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %%
chipo.value_counts('choice_description')
# Out:
# choice_description
# [Diet Coke]                                                                                                                134
# [Coke]                                                                                                                     123
# [Sprite]                                                                                                                    77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                      42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                           40
#                                                                                                                           ...
# [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Guacamole, Lettuce]]                                            1
# ...

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda c: float(c[1:]))

# %%
chipo['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
chipo['order_id'].nunique()
# Out:
# 1834

# %%
average_value = chipo['item_price'].sum() / chipo['order_id'].nunique()

# %%
average_value
# Out:
# 18.811428571428575

# %%
unique_items = chipo['item_name'].nunique()

# %%
unique_items
# Out:
# 50

# %% [markdown]
# # 🌟Exercise 2: Filtering & Sorting (Chipo)

# %%
chipo[chipo['item_price'] > 10]['item_name'].nunique()
# Out:
# 31

# %%
chipo['item_name'][chipo['item_price'] > 10].nunique()
# Out:
# 31

# %% [markdown]
# # 🌟 Exercise 3: Grouping (Users)

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.groupby('occupation').mean('age')['age']
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# # 🌟 Exercise 4: Merge (All_data, All_data_col, Data3)

# %%
data1 = users.head(10)

# %%
data1
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %%
data2 = users[20:89]

# %%
data2
# Out:
#     user_id  age gender     occupation zip_code
# 20       21   26      M         writer    30068
# 21       22   25      M         writer    40206
# 22       23   30      F         artist    48197
# 23       24   21      F         artist    94533
# 24       25   39      M       engineer    55107
# ..      ...  ...    ...            ...      ...
# 84       85   51      M       educator    20003
# 85       86   26      M  administrator    46005
# 86       87   47      M  administrator    89503
# 87       88   49      F      librarian    11701
# 88       89   43      F  administrator    68106
#
# [69 rows x 5 columns]

# %%
data3 = users.tail(105)

# %%
data3
# Out:
#      user_id  age gender     occupation zip_code
# 838      839   38      F  entertainment    90814
# 839      840   39      M         artist    55406
# 840      841   45      M         doctor    47401
# 841      842   40      M         writer    93055
# 842      843   35      M      librarian    44212
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [105 rows x 5 columns]

# %%
all_data = pd.concat([data1,data2], axis = 0)

# %%
all_data
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# ..      ...  ...    ...            ...      ...
# 84       85   51      M       educator    20003
# 85       86   26      M  administrator    46005
# 86       87   47      M  administrator    89503
# 87       88   49      F      librarian    11701
# 88       89   43      F  administrator    68106
#
# [79 rows x 5 columns]

# %%
all_data_col = pd.concat([data1,data2], axis = 1)

# %%
all_data_col
# Out:
#     user_id   age gender  occupation zip_code  user_id   age gender  \
# 0       1.0  24.0      M  technician    85711      NaN   NaN    NaN
# 1       2.0  53.0      F       other    94043      NaN   NaN    NaN
# 2       3.0  23.0      M      writer    32067      NaN   NaN    NaN
# 3       4.0  24.0      M  technician    43537      NaN   NaN    NaN
# 4       5.0  33.0      F       other    15213      NaN   NaN    NaN
# ..      ...   ...    ...         ...      ...      ...   ...    ...
# 84      NaN   NaN    NaN         NaN      NaN     85.0  51.0      M
# 85      NaN   NaN    NaN         NaN      NaN     86.0  26.0      M
# 86      NaN   NaN    NaN         NaN      NaN     87.0  47.0      M
# 87      NaN   NaN    NaN         NaN      NaN     88.0  49.0      F
# 88      NaN   NaN    NaN         NaN      NaN     89.0  43.0      F
#
#        occupation zip_code
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# ...

# %% [markdown]
# # 🌟 Exercise 5: Deleting (Iris)

# %%
data5 = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', sep=',')

# %%
data5
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data5.rename(columns={'5.1':'sepal_length'},inplace=True)

# %%
data5
# Out:
#      sepal_length  3.5  1.4  0.2     Iris-setosa
# 0             4.9  3.0  1.4  0.2     Iris-setosa
# 1             4.7  3.2  1.3  0.2     Iris-setosa
# 2             4.6  3.1  1.5  0.2     Iris-setosa
# 3             5.0  3.6  1.4  0.2     Iris-setosa
# 4             5.4  3.9  1.7  0.4     Iris-setosa
# ..            ...  ...  ...  ...             ...
# 144           6.7  3.0  5.2  2.3  Iris-virginica
# 145           6.3  2.5  5.0  1.9  Iris-virginica
# 146           6.5  3.0  5.2  2.0  Iris-virginica
# 147           6.2  3.4  5.4  2.3  Iris-virginica
# 148           5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data5.rename(columns={'3.5':'sepal_width'},inplace=True)

# %%
data5.rename(columns={'1.4':'petal_length'},inplace=True)

# %%
data5.rename(columns={'0.2':'petal_width'},inplace=True)

# %%
data5.rename(columns={'Iris-setosa':'species'},inplace=True)

# %%
data5
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data5[data5['species'].isnull()].count()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # 🌟 Exercise 6: Creating Series And DataFrames (Pokemon)

# %%
pokemon = pd.DataFrame({
    'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
    'hp': [45, 39, 44, 45],
    'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
    'pokedex': ['yes', 'no', 'yes', 'no'],
    'type': ['grass', 'fire', 'water', 'bug']
})

# %%
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %%
new = pokemon[['name', 'type', 'hp', 'evolution', 'pokedex']]

# %%
new
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# # 🌟 Exercise 8: Handling Time Series Data (Investor_data)

# %%
Investor_data = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv', sep=',')

# %%
Investor_data
# Out:
#           Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0   2012-12-05         -7426            -6060         -1367     -74
# 1   2012-12-12         -8783            -7520         -1263     123
# 2   2012-12-19         -5496            -5470           -26     -73
# 3   2012-12-26         -4451            -4076          -375     550
# 4   2013-01-02        -11156            -9622         -1533    -158
# 5   2013-01-09         14817             7995          6821    2888
# 6   2014-04-02          3155              938          2217     265
# 7   2014-04-09          5761             2080          3681    1482
# 8   2014-04-16          2286              634          1652    1186
# 9   2014-04-23          3530             1392          2138    1239
# 10  2014-04-30         -3890            -3996           106     759
# 11  2014-05-07           632            -2006          2639    -340
# 12  2014-05-14         -1079            -2321          1242    1188
# ...

# %%
Investor_data['Date'].value_counts()
# Out:
# 2012-12-05    1
# 2012-12-12    1
# 2014-08-20    1
# 2014-08-27    1
# 2014-09-03    1
# 2014-09-10    1
# 2014-11-05    1
# 2014-11-12    1
# 2014-11-19    1
# 2014-11-25    1
# 2015-01-07    1
# 2015-01-14    1
# 2015-01-21    1
# 2015-01-28    1
# 2015-02-04    1
# 2015-02-11    1
# 2015-03-04    1
# 2015-03-11    1
# 2015-03-18    1
# 2015-03-25    1
# 2015-04-01    1
# 2014-08-13    1
# 2014-08-06    1
# 2014-07-30    1
# 2014-04-30    1
# 2012-12-19    1
# 2012-12-26    1
# 2013-01-02    1
# 2013-01-09    1
# 2014-04-02    1
# 2014-04-09    1
# 2014-04-16    1
# 2014-04-23    1
# 2014-05-07    1
# 2014-07-09    1
# 2014-05-14    1
# 2014-05-21    1
# 2014-05-28    1
# 2014-06-04    1
# 2014-06-11    1
# 2014-06-18    1
# 2014-06-25    1
# 2014-07-02    1
# 2015-04-08    1
# Name: Date, dtype: int64

# %%
Investor_data.groupby(['Date']).size()
# Out:
# Date
# 2012-12-05    1
# 2012-12-12    1
# 2012-12-19    1
# 2012-12-26    1
# 2013-01-02    1
# 2013-01-09    1
# 2014-04-02    1
# 2014-04-09    1
# 2014-04-16    1
# 2014-04-23    1
# 2014-04-30    1
# 2014-05-07    1
# 2014-05-14    1
# 2014-05-21    1
# 2014-05-28    1
# 2014-06-04    1
# 2014-06-11    1
# 2014-06-18    1
# 2014-06-25    1
# 2014-07-02    1
# 2014-07-09    1
# 2014-07-30    1
# 2014-08-06    1
# 2014-08-13    1
# 2014-08-20    1
# 2014-08-27    1
# 2014-09-03    1
# 2014-09-10    1
# 2014-11-05    1
# 2014-11-12    1
# 2014-11-19    1
# 2014-11-25    1
# 2015-01-07    1
# 2015-01-14    1
# 2015-01-21    1
# 2015-01-28    1
# 2015-02-04    1
# 2015-02-11    1
# 2015-03-04    1
# 2015-03-11    1
# 2015-03-18    1
# 2015-03-25    1
# 2015-04-01    1
# 2015-04-08    1
# dtype: int64

# %%
Investor_data.set_index("Date", inplace=True)

# %%
Investor_data
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-05         -7426            -6060         -1367     -74        5317
# 2012-12-12         -8783            -7520         -1263     123        1818
# 2012-12-19         -5496            -5470           -26     -73         103
# 2012-12-26         -4451            -4076          -375     550        2610
# 2013-01-02        -11156            -9622         -1533    -158        2383
# 2013-01-09         14817             7995          6821    2888        9766
# 2014-04-02          3155              938          2217     265        3379
# 2014-04-09          5761             2080          3681    1482        1609
# 2014-04-16          2286              634          1652    1186         633
# 2014-04-23          3530             1392          2138    1239        1984
# 2014-04-30         -3890            -3996           106     759         888
# ...

# %% [markdown]
# # 🌟 Exercise 7: Descriptive Statistics (Baby_names)

# %%
baby_names = pd.read_csv('https://drive.google.com/open?id=1At_YCsguCIEqe3l-gSPPquaOORbGLKmj', sep=',')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Users\CD86~1\AppData\Local\Temp/ipykernel_11436/4267392840.py in <module>
# ----> 1 baby_names = pd.read_csv('https://drive.google.com/open?id=1At_YCsguCIEqe3l-gSPPquaOORbGLKmj', sep=',')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
baby_names.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CD86~1\AppData\Local\Temp/ipykernel_11436/2619363783.py in <module>
# ----> 1 baby_names.head(10)
#
# NameError: name 'baby_names' is not defined

# %%
baby_names.drop(['Unnamed: 0', 'Id'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CD86~1\AppData\Local\Temp/ipykernel_11436/3748182809.py in <module>
# ----> 1 baby_names.drop(['Unnamed: 0', 'Id'], axis=1)
#
# NameError: name 'baby_names' is not defined
